# %%
import pandas as pd
import numpy as np
import scipy as sp

import seaborn as sns

from sklearn.metrics.pairwise import cosine_similarity

import sys

# %%
student_data = pd.read_excel("dataset/StudentInformationTable.xlsx")
course_data = pd.read_excel("dataset/CourseInformationTable.xlsx")
career_data = pd.read_excel("dataset/CourseSelectionTable.xlsx")

display(student_data.describe())
display(student_data.head(5))
# Out:
#          StudentId  EnrollmentYear
# count  4568.000000     4568.000000
# mean   2284.500000     2018.295972
# std    1318.812344        1.191886
# min       1.000000     2000.000000
# 25%    1142.750000     2018.000000
# 50%    2284.500000     2019.000000
# 75%    3426.250000     2019.000000
# max    4568.000000     2020.000000
#    StudentId  EnrollmentYear      Education                     Major
# 0       1115            2018  Undergraduate        Biological Science
# 1       1108            2018  Undergraduate        Biological Science
# 2       1192            2018  Undergraduate  Urban and Rural Planning
# 3       1193            2018  Undergraduate  Urban and Rural Planning
# 4       1293            2018  Undergraduate             World History

# %%
display(course_data.describe())
display(course_data.head(5))
# Out:
#           CourseId        Grade
# count  5591.000000  5225.000000
# mean   2796.000000     2.436842
# std    1614.127009     0.939362
# min       1.000000     0.000000
# 25%    1398.500000     2.000000
# 50%    2796.000000     2.000000
# 75%    4193.500000     3.000000
# max    5591.000000    12.000000
#    CourseId                           CourseName  \
# 0       362                    Fascinating Robot
# 1      1045           Introduction to Seismology
# 2      1647  Speeches and oral cultures in China
# 3      1830               Modern Chinese History
# 4      1834               Chinese Historiography
#
#                                          College                     Type  \
# 0                         College of Engineering    Whole school optional
# 1             School of Earth and Space Sciences  General elective course
# 2  Department of Chinese Language and Literature    Whole school optional
# 3                          Department of History           Required major
# 4                          Department of History                 optional
#
#    Grade             Prerequisite  \
# 0    2.0                      NaN
# 1    2.0                      NaN
# 2    2.0                      NaN
# 3    4.0  ancient Chinese history
# 4    3.0                      NaN
#
#                                         Introduction
# 0  This course is open to all students in the sch...
# 1  This course is a quality education general cou...
# 2  The course is based on the introduction and re...
# 3  This course is based on a large number of orig...
# 4  This course is a compulsory course for undergr...

# %%
display(career_data.describe())
display(career_data.head(5))
# Out:
#            StudentId       Semester       CourseId          Score
# count  208949.000000  208941.000000  208949.000000  149223.000000
# mean     1878.772590       1.505344    2578.111147      81.154792
# std      1245.936537       0.532999    1732.925391      13.841620
# min         1.000000       1.000000       1.000000       0.000000
# 25%       778.000000       1.000000     750.000000      78.000000
# 50%      1695.000000       1.000000    2569.000000      84.000000
# 75%      2914.000000       2.000000    4151.000000      90.000000
# max      4568.000000       3.000000    5591.000000     100.000000
#    StudentId AcademicYear  Semester  CourseId  \
# 0       1115        18-19       1.0       146
# 1       1115        18-19       1.0       148
# 2       1115        18-19       1.0       654
# 3       1115        18-19       1.0       681
# 4       1115        18-19       1.0       684
#
#                                   CourseName  \
# 0               Advanced Mathematics (B) (1)
# 1  Problem-solving on Higher Mathematics (B)
# 2                 General Chemistry Practice
# 3                      General Chemistry (B)
# 4                  General Chemistry Lab.（B）
#
#                             CourseCollege  Score
# 0          National School of Development   81.0
# 1                     School of Economics    NaN
# 2                  College of Engineering    NaN
# 3  Department of Medicine Teaching office   72.0
# 4  Department of Medicine Teaching office   83.5

# %%
career_data_clean = career_data.dropna()

# %%
print("Number of students in data:  ", career_data_clean.StudentId.nunique())
print("Range of scores:             ", career_data_clean.Score.min(), career_data_clean.Score.max())
print("Unique scores in dataset:    ")
print(np.array(sorted(career_data_clean.Score.unique())))
# Out:
# Number of students in data:   4546
# Range of scores:              0.0 100.0
# Unique scores in dataset:
# [  0.    1.    1.5   2.    2.5   3.    3.5   4.    5.    5.5   6.    7.
#    7.5   8.    9.    9.5  10.   11.   12.   12.5  13.   14.   14.5  15.
#   16.   16.5  17.   18.   19.   19.5  20.   20.5  21.   22.   22.5  23.
#   23.5  23.6  24.   25.   25.5  26.   27.   27.5  28.   28.5  29.   30.
#   30.5  31.   32.   33.   34.   34.5  35.   35.5  36.   36.5  37.   37.5
#   38.   38.5  39.   39.5  40.   40.5  41.   41.5  42.   42.5  43.   43.5
#   44.   44.5  45.   45.5  46.   46.5  47.   47.5  48.   48.5  49.   49.5
#   50.   50.5  51.   51.5  52.   52.5  53.   53.5  54.   54.5  55.   55.5
#   56.   56.5  57.   57.5  58.   59.   59.5  60.   60.5  61.   61.5  62.
#   62.5  63.   63.5  64.   64.5  65.   65.5  66.   66.5  66.6  67.   67.5
#   68.   68.5  69.   69.5  70.   70.5  70.7  71.   71.5  72.   72.5  73.
#   73.5  74.   74.5  75.   75.5  76.   76.5  77.   77.5  78.   78.5  79.
#   79.5  80.   80.5  80.8  81.   81.3  81.5  81.7  82.   82.1  82.5  83.
#   83.3  83.4  83.5  83.6  84.   84.5  84.7  85.   85.2  85.3  85.5  85.7
#   85.9  86.   86.5  86.7  86.9  87.   87.1  87.4  87.5  87.7  88.   88.3
#   88.5  88.6  88.7  89.   89.3  89.5  90.   90.5  90.6  90.7  90.9  91.
#   91.1  91.2  91.3  91.4  91.5  91.6  91.8  92.   92.1  92.3  92.4  92.5
#   92.7  92.9  93.   93.1  93.2  93.4  93.5  93.6  93.8  94.   94.2  94.5
#   94.6  95.   95.3  95.4  95.5  95.6  95.8  95.9  96.   96.5  96.6  96.8
#   97.   97.5  97.8  98.   98.2  98.5  99.   99.4  99.5 100. ]

# %%
career_student_data = pd.merge(career_data_clean, student_data, 'inner', 'StudentId')

# %%
display(career_student_data.describe())
display(career_student_data.head(5))
# Out:
#            StudentId       Semester       CourseId          Score  \
# count  149021.000000  149021.000000  149021.000000  149021.000000
# mean     1631.926044       1.430362    2723.731306      81.136139
# std      1163.655105       0.527811    1690.240923      13.840801
# min         1.000000       1.000000       2.000000       0.000000
# 25%       617.000000       1.000000    1103.000000      78.000000
# 50%      1411.000000       1.000000    2740.000000      84.000000
# 75%      2592.000000       2.000000    4152.000000      90.000000
# max      4568.000000       3.000000    5591.000000     100.000000
#
#        EnrollmentYear
# count   149021.000000
# mean      2017.849874
# std          1.213044
# min       2000.000000
# 25%       2017.000000
# 50%       2018.000000
# 75%       2019.000000
# max       2020.000000
#    StudentId AcademicYear  Semester  CourseId                    CourseName  \
# 0       1115        18-19       1.0       146  Advanced Mathematics (B) (1)
# 1       1115        18-19       1.0       681         General Chemistry (B)
# 2       1115        18-19       1.0       684     General Chemistry Lab.（B）
# 3       1115        18-19       1.0       748                    Physiology
# 4       1115        18-19       1.0       844               Physiology Lab.
#
#                             CourseCollege  Score  EnrollmentYear  \
# 0          National School of Development   81.0            2018
# 1  Department of Medicine Teaching office   72.0            2018
# 2  Department of Medicine Teaching office   83.5            2018
# 3                College of Life Sciences   85.0            2018
# 4                College of Life Sciences   75.0            2018
#
#        Education               Major
# 0  Undergraduate  Biological Science
# 1  Undergraduate  Biological Science
# 2  Undergraduate  Biological Science
# 3  Undergraduate  Biological Science
# 4  Undergraduate  Biological Science

# %%
all_student_ids = career_student_data.StudentId.unique()
training_students = np.random.choice(all_student_ids, int(all_student_ids.size * .8), False)
testing_students = np.array([i for i in all_student_ids if i not in training_students])
training_data = career_student_data[career_student_data["StudentId"].isin(training_students)]
testing_data = career_student_data[career_student_data["StudentId"].isin(testing_students)]
print("Number of total students:    ", all_student_ids.size)
print("Number of training students: ", training_students.size)
print("Number of testing students:  ", testing_students.size)
display(training_data.describe())
display(testing_data.describe())
# Out:
# Number of total students:     4546
# Number of training students:  3636
# Number of testing students:   910
#            StudentId       Semester       CourseId          Score  \
# count  119041.000000  119041.000000  119041.000000  119041.000000
# mean     1642.321015       1.430129    2728.229568      81.215581
# std      1166.630566       0.527416    1688.917476      13.754281
# min         1.000000       1.000000       2.000000       0.000000
# 25%       624.000000       1.000000    1110.000000      78.000000
# 50%      1424.000000       1.000000    2762.000000      84.000000
# 75%      2625.000000       2.000000    4152.000000      90.000000
# max      4568.000000       3.000000    5591.000000     100.000000
#
#        EnrollmentYear
# count   119041.000000
# mean      2017.859208
# std          1.215396
# min       2000.000000
# 25%       2017.000000
# 50%       2018.000000
# 75%       2019.000000
# max       2020.000000
#           StudentId      Semester      CourseId         Score  EnrollmentYear
# count  29980.000000  29980.000000  29980.000000  29980.000000    29980.000000
# mean    1590.650934      1.431288   2705.870147     80.820700     2017.812809
# std     1150.857732      0.529381   1695.396165     14.174979        1.202967
# min        5.000000      1.000000      9.000000      0.000000     2014.000000
# 25%      595.000000      1.000000   1045.000000     77.000000     2017.000000
# 50%     1365.000000      1.000000   2687.000000     84.000000     2018.000000
# 75%     2466.000000      2.000000   4152.000000     90.000000     2019.000000
# max     4559.000000      3.000000   5591.000000    100.000000     2020.000000

# %%
training_data.head()
# Out:
#      StudentId AcademicYear  Semester  CourseId  \
# 98        1192        18-19       1.0       165
# 99        1192        18-19       1.0      1121
# 100       1192        18-19       1.0      1138
# 101       1192        18-19       1.0      1258
# 102       1192        18-19       1.0      1656
#
#                              CourseName  \
# 98         Advanced Mathematics (C) (I)
# 99                      Human Geography
# 100  Introduction to Physical Geography
# 101          Introduction to Psychology
# 102            University-level Chinese
#
#                                       CourseCollege  Score  EnrollmentYear  \
# 98           Department of Medicine Teaching office   99.0            2018
# 99      College of Urban and Environmental Sciences   91.0            2018
# 100     College of Urban and Environmental Sciences   82.0            2018
# 101  School of Psychological and Cognitive Sciences   85.5            2018
# 102   Department of Chinese Language and Literature   94.0            2018
#
#          Education                     Major
# 98   Undergraduate  Urban and Rural Planning
# 99   Undergraduate  Urban and Rural Planning
# 100  Undergraduate  Urban and Rural Planning
# 101  Undergraduate  Urban and Rural Planning
# 102  Undergraduate  Urban and Rural Planning

# %%
training_data["CourseName"].nunique()
# Out:
# 3231

# %%
training_data["CourseName"].value_counts().head()
# Out:
# Military Theory                                            2824
# An Introduction to Ideological & Moral Culture and Laws    2598
# Outline of Chinese Modern History                          2514
# Events and Policies                                        2032
# Advanced Mathematics (B) (1)                               1817
# Name: CourseName, dtype: int64

# %%
score_counts = pd.DataFrame(training_data["CourseName"].value_counts())
rare_courses = score_counts[score_counts["CourseName"] <= 200].index

common_courses = training_data[training_data["CourseName"].isin(rare_courses)]
common_courses.shape
# Out:
# (60559, 10)

# %%
common_courses["CourseName"].nunique()
# Out:
# 3118

# %%
user_course_df = common_courses.pivot_table(index=["StudentId"], columns=["CourseName"], values="Score")

user_course_df.shape
# Out:
# (3159, 3118)

# %%
user_course_df.head(10)
# Out:
# CourseName  \nHealth Physics   American Poetry  \
# StudentId
# 1                        NaN               NaN
# 2                        NaN               NaN
# 3                        NaN               NaN
# 4                        NaN               NaN
# 7                        NaN               NaN
# 9                        NaN               NaN
# 10                       NaN               NaN
# 11                       NaN               NaN
# 12                       NaN               NaN
# 13                       NaN              82.0
#
# CourseName   China's Foreign Relations from Ambassadors' Perspective  \
# StudentId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 7                                                         NaN
# 9                                                         NaN
# 10                                                        NaN
# 11                                                        NaN
# 12                                                        NaN
# 13                                                        NaN
#
# CourseName   Consumer Health Information   Daoyin   \
# StudentId
# 1                                    NaN       NaN
# 2                                    NaN       NaN
# 3                                    NaN       NaN
# 4                                    NaN       NaN
# 7                                    NaN       NaN
# 9                                    NaN       NaN
# 10                                   NaN       NaN
# 11                                   NaN       NaN
# 12                                   NaN       NaN
# 13                                   NaN       NaN
#
# CourseName   Death Talks in China and the West   Enterprise & Corporation Law  \
# StudentId
# 1                                          NaN                            NaN
# 2                                          NaN                            NaN
# 3                                          NaN                            NaN
# 4                                          NaN                            NaN
# 7                                          NaN                            NaN
# 9                                          NaN                            NaN
# 10                                         NaN                            NaN
# 11                                         NaN                            NaN
# 12                                         NaN                            NaN
# 13                                         NaN                            NaN
#
# CourseName   Environmental Geosciences    Graduation Screenwriting（1）  \
# StudentId
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
# 7                                   NaN                           NaN
# 9                                   NaN                           NaN
# 10                                  NaN                           NaN
# 11                                  NaN                           NaN
# 12                                  NaN                           NaN
# 13                                  NaN                           NaN
#
# CourseName   Graduation Screenwriting（2）  ...  the Evidence Law  \
# StudentId                                 ...
# 1                                    NaN  ...               NaN
# 2                                    NaN  ...               NaN
# 3                                    NaN  ...               NaN
# 4                                    NaN  ...               NaN
# 7                                    NaN  ...               NaN
# 9                                    NaN  ...               NaN
# 10                                   NaN  ...               NaN
# 11                                   NaN  ...               NaN
# 12                                   NaN  ...               NaN
# 13                                   NaN  ...               NaN
#
# CourseName  the development of modern news  \
# StudentId
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 7                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
#
# CourseName  the leading edges of genetics, development and cell biology  \
# StudentId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 7                                                         NaN
# 9                                                         NaN
# 10                                                        NaN
# 11                                                        NaN
# 12                                                        NaN
# 13                                                        NaN
#
# CourseName  the reform of admissions of china  the study of society  \
# StudentId
# 1                                         NaN                   NaN
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4                                         NaN                   NaN
# 7                                         NaN                   NaN
# 9                                         NaN                   NaN
# 10                                        NaN                   NaN
# 11                                        NaN                   NaN
# 12                                        NaN                   NaN
# 13                                        NaN                   NaN
#
# CourseName  the study on  the mechanism of Chinese internet literature  \
# StudentId
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 7                                                         NaN
# 9                                                         NaN
# 10                                                        NaN
# 11                                                        NaN
# 12                                                        NaN
# 13                                                        NaN
#
# CourseName  traditional  Chinese Literary Theory  \
# StudentId
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 7                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
#
# CourseName  workshop for energy and environment engineeing  \
# StudentId
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 7                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
#
# CourseName  Ｉｎｔｅｒｎａｔｉｏｎａｌ Ｉｎｖｅｓｔｍｅｎｔ  Ｉｎｔｅｒｎａｔｉｏｎａｌ　Ｅｃｏｎｏｍｉｃｓ
# StudentId
# 1                                NaN                      NaN
# 2                                NaN                      NaN
# 3                                NaN                      NaN
# 4                                NaN                      NaN
# 7                                NaN                      NaN
# 9                                NaN                      NaN
# 10                               NaN                      NaN
# 11                               NaN                      NaN
# 12                               NaN                      NaN
# 13                               NaN                      NaN
#
# [10 rows x 3118 columns]

# %%
course_name = "the development of modern news"
course_name = user_course_df[course_name]
user_course_df.corrwith(course_name).sort_values(ascending=False).head(10)
# Out:
# c:\Users\Khaled\anaconda3\envs\ml\lib\site-packages\numpy\lib\function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# c:\Users\Khaled\anaconda3\envs\ml\lib\site-packages\numpy\lib\function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# CourseName
# Ｉｎｔｅｒｎａｔｉｏｎａｌ　Ｅｃｏｎｏｍｉｃｓ                                 1.0
# Introduction to Information Resource Management         1.0
# Social Anthropology                                     1.0
# Physiography                                            1.0
# Experiments of Experimental Psychology                  1.0
# Basic Reporting and Writing Skills                      1.0
# Philosophy and Human Life                               1.0
# Introduction to Contemporary Art                        1.0
# Beijing and Shanghai: Twin Cities in Chinese History    1.0
# Studies on Famous Works of Modern Chinese Literature    1.0
# dtype: float64

# %%
random_user = 1192
random_user_df = user_course_df[user_course_df.index == random_user]
random_user_df
# Out:
# CourseName  \nHealth Physics   American Poetry  \
# StudentId
# 1192                     NaN               NaN
#
# CourseName   China's Foreign Relations from Ambassadors' Perspective  \
# StudentId
# 1192                                                      NaN
#
# CourseName   Consumer Health Information   Daoyin   \
# StudentId
# 1192                                 NaN       NaN
#
# CourseName   Death Talks in China and the West   Enterprise & Corporation Law  \
# StudentId
# 1192                                       NaN                            NaN
#
# CourseName   Environmental Geosciences    Graduation Screenwriting（1）  \
# StudentId
# 1192                                NaN                           NaN
#
# CourseName   Graduation Screenwriting（2）  ...  the Evidence Law  \
# StudentId                                 ...
# 1192                                 NaN  ...               NaN
#
# CourseName  the development of modern news  \
# StudentId
# 1192                                   NaN
#
# CourseName  the leading edges of genetics, development and cell biology  \
# StudentId
# 1192                                                      NaN
#
# CourseName  the reform of admissions of china  the study of society  \
# StudentId
# 1192                                      NaN                   NaN
#
# CourseName  the study on  the mechanism of Chinese internet literature  \
# StudentId
# 1192                                                      NaN
#
# CourseName  traditional  Chinese Literary Theory  \
# StudentId
# 1192                                         NaN
#
# CourseName  workshop for energy and environment engineeing  \
# StudentId
# 1192                                                   NaN
#
# CourseName  Ｉｎｔｅｒｎａｔｉｏｎａｌ Ｉｎｖｅｓｔｍｅｎｔ  Ｉｎｔｅｒｎａｔｉｏｎａｌ　Ｅｃｏｎｏｍｉｃｓ
# StudentId
# 1192                             NaN                      NaN
#
# [1 rows x 3118 columns]

# %%
courses_taken = random_user_df.columns[random_user_df.notna().any()].tolist()
print(len(courses_taken))
courses_taken
# Out:
# 39
# ['Advanced Mathematics (C) (I)',
#  'Advanced Mathematics (C) (II)',
#  'Architecture Design I',
#  'Art of Novel',
#  'Chinese SanShou',
#  'Comparative Readings of ？English Classics and Their ChineseTranslations',
#  'Cultural Geography',
#  'Economic Geography',
#  'Fine Arts: Sketch and Color',
#  'History of Chinese and Foreign City Planning',
#  'Human Geography',
#  'Intriguing science of the solar system',
#  'Introduction to Microelectronics',
#  'Introduction to Philosophy',
#  'Introduction to Physical Geography',
#  'Japan and Japanese Studies',
#  'Japanese Economy',
#  'Kendo',
#  'Modern and Contemporary Architecture',
#  'Population Geography',
#  'Practice of Fine Arts',
#  'Principles of Geographic Information System',
#  'Principles of Urban Planning (1)',
#  'Principles of Urban Planning (2)',
#  'Quantitative Geography and System Engineering for City Planning',
#  'Selective Readings in Western Civilization',
#  'Social History of Medieval Western Europe',
#  'Special Topics in China’s Reform',
#  'Statistics',
#  'Urban Ecology and Environmental Planning',
#  'Urban Economics',
#  'Urban Geography',
#  'Urban Infrastructure Planning',
#  'Urban Road System and Transportation Planning',
#  'Urban Social Geography',
#  'Urban Spatial Structure',
#  'Urban and Rural Community Planning and Design',
#  'Value Assessment of Real Estate',
#  'comparative constitutional Law']

# %%
user_course_df.loc[user_course_df.index == random_user, user_course_df.columns == "Art of Novel"]
# Out:
# CourseName  Art of Novel
# StudentId
# 1192                89.0

# %%
courses_taken_df = user_course_df[courses_taken]
courses_taken_df.head()
courses_taken_df.shape
# Out:
# (3159, 39)

# %%
user_course_count = courses_taken_df.T.notnull().sum()

user_course_count = user_course_count.reset_index()
user_course_count.columns = ["studentId","course_count"]
user_course_count.head()
# Out:
#    studentId  course_count
# 0          1             0
# 1          2             0
# 2          3             3
# 3          4             1
# 4          7             0

# %%
perc = len(courses_taken) * 60 / 100
perc
# Out:
# 23.4

# %%
users_same_courses = user_course_count[user_course_count["course_count"] > perc]["studentId"]
users_same_courses.count()
# Out:
# 1

# %%
# Let's combine the data of user #28491 and similar users:
final_df = pd.concat([courses_taken_df[courses_taken_df.index.isin(users_same_courses)],
                      random_user_df[courses_taken]])

final_df.shape
final_df.T.corr()
# Out:
# StudentId  1192  1192
# StudentId
# 1192        1.0   1.0
# 1192        1.0   1.0

# %%
corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
corr_df = pd.DataFrame(corr_df, columns=["corr"])
corr_df.index.names = ['user_id_1', 'user_id_2']
corr_df = corr_df.reset_index()
corr_df.head()
# Out:
#    user_id_1  user_id_2  corr
# 0       1192       1192   1.0
